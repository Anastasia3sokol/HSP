# %%
import re

# %%
paml = open('../../Body/2_Derived/ENSG00000284701_TMEM247_paml_branch_model_2.txt').readlines()

# %%
dn_ds_tree = ''.join(paml)[''.join(paml).find('w ratios as labels for TreeView:'):].split('\n')[1]

# %%
dn_tree = ''.join(paml)[''.join(paml).find('dN tree:'):].split('\n')[1]
ds_tree = ''.join(paml)[''.join(paml).find('dS tree:'):].split('\n')[1]

# %%
sp = {x.split(': ')[0] : [x.split(': ')[1]] for x in re.findall('[A-Z][a-z]+_[a-z]+_?[a-z]*:\s[0-9]+\.[0-9]*', dn_tree)}

[sp[x.split(': ')[0]].append(x.split(': ')[1]) for x in re.findall('[A-Z][a-z]+_[a-z]+_?[a-z]*:\s[0-9]+\.[0-9]*', ds_tree)]


[sp[x.split(' #')[0]].append(x.split(' #')[1]) for x in re.findall('[A-Z][a-z]+_[a-z]+_?[a-z]*\s#[0-9]+\.[0-9]*', dn_ds_tree)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
sp
# Out:
# {'Castor_canadensis': ['0.031763', '0.118118', '0.2689'],
#  'Dipodomys_ordii': ['0.048215', '0.304815', '0.1582'],
#  'Fukomys_damarensis': ['0.066617', '0.289104', '0.2304'],
#  'Cricetulus_griseus': ['0.023108', '0.109310', '0.2114'],
#  'Microtus_ochrogaster': ['0.015693', '0.172512', '0.0910'],
#  'Peromyscus_maniculatus': ['0.020676', '0.145875', '0.1417'],
#  'Meriones_unguiculatus': ['0.022756', '0.120860', '0.1883'],
#  'Mus_caroli': ['0.004851', '0.025280', '0.1919'],
#  'Mus_spretus': ['0.004717', '0.029311', '0.1609'],
#  'Mus_musculus': ['0.000001', '0.006200', '0.0001'],
#  'Mus_pahari': ['0.002356', '0.027408', '0.0860'],
#  'Rattus_norvegicus': ['0.010094', '0.072503', '0.1392'],
#  'Nannospalax_galili': ['0.030359', '0.163288', '0.1859'],
#  'Ictidomys_tridecemlineatus': ['0.002117', '0.025812', '0.0820'],
#  'Marmota_marmota_marmota': ['0.002328', '0.023043', '0.1010'],
#  'Ochotona_princeps': ['0.033903', '0.195656', '0.1733'],
#  'Oryctolagus_cuniculus': ['0.060070', '0.393254', '0.1528'],
#  'Aotus_nancymaae': ['0.013673', '0.031595', '0.4327'],
#  'Callithrix_jacchus': ['0.013717', '0.096784', '0.1417'],
#  'Saimiri_boliviensis': ['0.011254', '0.023330', '0.4824'],
#  'Cebus_capucinus': ['0.006667', '0.007282', '0.9155'],
#  'Cercocebus_atys': ['0.006051', '0.021700', '0.2789'],
#  'Papio_anubis': ['0.002000', '0.007112', '0.2812'],
#  'Mandrillus_leucophaeus': ['0.000000', '0.000006', '0.0001'],
#  'Macaca_fascicularis': ['0.000000', '0.000006', '0.0001'],
#  'Macaca_nemestrina': ['0.000001', '0.006993', '0.0001'],
#  'Macaca_mulatta': ['0.000000', '0.000006', '0.0001'],
#  'Chlorocebus_sabaeus': ['0.001979', '0.006943', '0.2851'],
#  'Colobus_angolensis': ['0.004061', '0.014243', '0.2851'],
#  'Piliocolobus_tephrosceles': ['0.008136', '0.007098', '1.1463'],
#  'Rhinopithecus_bieti': ['0.002123', '0.000002', '999.0000'],
#  'Rhinopithecus_roxellana': ['0.000000', '0.000006', '0.0001'],
#  'Gorilla_gorilla': ['0.007843', '0.014545', '0.5392'],
#  'Homo_sapiens': ['0.007993', '0.014515', '0.5506'],
#  'Pan_paniscus': ['0.006006', '0.014433', '0.4161'],
#  'Pan_troglodytes': ['0.008799', '0.000009', '999.0000'],
#  'Pongo_abelii': ['0.004121', '0.006831', '0.6033'],
#  'Carlito_syrichta': ['0.062424', '0.241323', '0.2587'],
#  'Microcebus_murinus': ['0.026737', '0.143547', '0.1863'],
#  'Propithecus_coquereli': ['0.023949', '0.090771', '0.2638'],
#  'Otolemur_garnettii': ['0.039746', '0.138739', '0.2865'],
#  'Tupaia_belangeri': ['0.000002', '0.000000', '173.2974'],
#  'Tupaia_chinensis': ['0.000000', '0.000006', '0.0001'],
#  'Galeopterus_variegatus': ['0.048988', '0.133694', '0.3664'],
#  'Chrysochloris_asiatica': ['0.046369', '0.244949', '0.1893'],
#  'Elephantulus_edwardii': ['0.024663', '0.347606', '0.0709'],
#  'Loxodonta_africana': ['0.011823', '0.074686', '0.1583'],
#  'Orycteropus_afer_afer': ['0.045027', '0.142812', '0.3153'],
#  'Procavia_capensis': ['0.051571', '0.144797', '0.3562'],
#  'Trichechus_manatus_latirostris': ['0.015887', '0.045030', '0.3528'],
#  'Dasypus_novemcinctus': ['0.048418', '0.220162', '0.2199'],
#  'Condylura_cristata': ['0.028861', '0.298067', '0.0968'],
#  'Eptesicus_fuscus': ['0.020415', '0.064927', '0.3144'],
#  'Myotis_davidii': ['0.004538', '0.043651', '0.1040'],
#  'Myotis_brandtii': ['0.004507', '0.000005', '999.0000'],
#  'Myotis_lucifugus': ['0.002259', '0.025512', '0.0885'],
#  'Miniopterus_natalensis': ['0.046470', '0.103470', '0.4491'],
#  'Hipposideros_armiger': ['0.024582', '0.053633', '0.4583'],
#  'Rhinolophus_sinicus': ['0.026163', '0.039000', '0.6709'],
#  'Pteropus_alecto': ['0.000002', '0.024171', '0.0001'],
#  'Pteropus_vampyrus': ['0.004685', '0.007706', '0.6079'],
#  'Rousettus_aegyptiacus': ['0.014347', '0.071151', '0.2016'],
#  'Balaenoptera_acutorostrata_scammoni': ['0.006190', '0.043877', '0.1411'],
#  'Delphinapterus_leucas': ['0.004244', '0.000004', '999.0000'],
#  'Orcinus_orca': ['0.002159', '0.016934', '0.1275'],
#  'Tursiops_truncatus': ['0.002059', '0.000002', '999.0000'],
#  'Lipotes_vexillifer': ['0.035641', '0.053259', '0.6692'],
#  'Physeter_catodon': ['0.022306', '0.045197', '0.4935'],
#  'Bison_bison_bison': ['0.000002', '0.016666', '0.0001'],
#  'Bos_mutus': ['0.006532', '0.000007', '999.0000'],
#  'Bos_indicus': ['0.002134', '0.000002', '999.0000'],
#  'Bos_taurus': ['0.004304', '0.007737', '0.5563'],
#  'Bubalus_bubalis': ['0.004319', '0.040452', '0.1068'],
#  'Capra_hircus': ['0.000002', '0.015784', '0.0001'],
#  'Ovis_aries': ['0.006393', '0.024268', '0.2634'],
#  'Pantholops_hodgsonii': ['0.006956', '0.015722', '0.4424'],
#  'Odocoileus_virginianus_texanus': ['0.016445', '0.034832', '0.4721'],
#  'Camelus_bactrianus': ['0.000001', '0.008227', '0.0001'],
#  'Camelus_ferus': ['0.000000', '0.000006', '0.0001'],
#  'Camelus_dromedarius': ['0.002045', '0.000002', '999.0000'],
#  'Sus_scrofa': ['0.017226', '0.096198', '0.1791'],
#  'Ceratotherium_simum_simum': ['0.003926', '0.075719', '0.0519'],
#  'Equus_asinus': ['0.000000', '0.000006', '0.0001'],
#  'Equus_przewalskii': ['0.000000', '0.000006', '0.0001'],
#  'Equus_caballus': ['0.004188', '0.000004', '999.0000'],
#  'Ailuropoda_melanoleuca': ['0.023643', '0.029216', '0.8092'],
#  'Ursus_maritimus': ['0.009880', '0.033036', '0.2991'],
#  'Enhydra_lutris_kenyoni': ['0.002101', '0.019131', '0.1098'],
#  'Mustela_putorius': ['0.002115', '0.025507', '0.0829'],
#  'Leptonychotes_weddellii': ['0.004282', '0.025062', '0.1708'],
#  'Neomonachus_schauinslandi': ['0.002137', '0.024075', '0.0888'],
#  'Odobenus_rosmarus_divergens': ['0.011172', '0.054431', '0.2053'],
#  'Canis_familiaris': ['0.012599', '0.202796', '0.0621'],
#  'Panthera_pardus': ['0.000002', '0.024012', '0.0001'],
#  'Panthera_tigris_altaica': ['0.000000', '0.000006', '0.0001'],
#  'Felis_catus': ['0.002113', '0.008176', '0.2585'],
#  'Acinonyx_jubatus': ['0.004652', '0.008833', '0.5267'],
#  'Notamacropus_eugenii': ['0.024589', '0.101236', '0.2429'],
#  'Phascolarctos_cinereus': ['0.000012', '0.118204', '0.0001'],
#  'Sarcophilus_harrisii': ['0.000020', '0.201490', '0.0001']}

# %%
dn_ds_1 = [x[2] for x in list(sp.values())]

# %%
dn_ds_2 = [x[2] for x in list(sp.values())]

# %%
for i,j in zip(dn_ds_1, dn_ds_2):
    print(i,j)
# Out:
# 0.2689 0.2689
# 0.1582 0.1582
# 0.2304 0.2304
# 0.2114 0.2114
# 0.0910 0.0910
# 0.1417 0.1417
# 0.1883 0.1883
# 0.1919 0.1919
# 0.1609 0.1609
# 0.0001 0.0001
# 0.0860 0.0860
# 0.1392 0.1392
# 0.1859 0.1859
# 0.0820 0.0820
# 0.1010 0.1010
# 0.1733 0.1733
# 0.1528 0.1528
# 0.4327 0.4327
# 0.1417 0.1417
# 0.4824 0.4824
# 0.9155 0.9155
# 0.2789 0.2789
# 0.2812 0.2812
# 0.0001 0.0001
# 0.0001 0.0001
# 0.0001 0.0001
# 0.0001 0.0001
# 0.2851 0.2851
# 0.2851 0.2851
# 1.1463 1.1463
# 999.0000 999.0000
# 0.0001 0.0001
# 0.5392 0.5392
# 0.5506 0.5506
# 0.4161 0.4161
# 999.0000 999.0000
# 0.6033 0.6033
# 0.2587 0.2587
# 0.1863 0.1863
# 0.2638 0.2638
# 0.2865 0.2865
# 173.2974 173.2974
# 0.0001 0.0001
# 0.3664 0.3664
# 0.1893 0.1893
# 0.0709 0.0709
# 0.1583 0.1583
# 0.3153 0.3153
# 0.3562 0.3562
# 0.3528 0.3528
# 0.2199 0.2199
# 0.0968 0.0968
# 0.3144 0.3144
# 0.1040 0.1040
# 999.0000 999.0000
# 0.0885 0.0885
# 0.4491 0.4491
# 0.4583 0.4583
# 0.6709 0.6709
# 0.0001 0.0001
# 0.6079 0.6079
# 0.2016 0.2016
# 0.1411 0.1411
# 999.0000 999.0000
# 0.1275 0.1275
# 999.0000 999.0000
# 0.6692 0.6692
# 0.4935 0.4935
# 0.0001 0.0001
# 999.0000 999.0000
# 999.0000 999.0000
# 0.5563 0.5563
# 0.1068 0.1068
# 0.0001 0.0001
# 0.2634 0.2634
# 0.4424 0.4424
# 0.4721 0.4721
# 0.0001 0.0001
# 0.0001 0.0001
# 999.0000 999.0000
# 0.1791 0.1791
# 0.0519 0.0519
# 0.0001 0.0001
# 0.0001 0.0001
# 999.0000 999.0000
# 0.8092 0.8092
# 0.2991 0.2991
# 0.1098 0.1098
# 0.0829 0.0829
# 0.1708 0.1708
# 0.0888 0.0888
# 0.2053 0.2053
# 0.0621 0.0621
# 0.0001 0.0001
# 0.0001 0.0001
# 0.2585 0.2585
# 0.5267 0.5267
# 0.2429 0.2429
# 0.0001 0.0001
# 0.0001 0.0001

# %%
with open('../../Body/2_Derived/ENSG00000284701_TMEM247_paml_branch_model_species_specific_dn_ds.txt', 'w') as f:
    head = 'Species' + '\t' + 'dN' + '\t' + 'dS' + '\t' + 'dN/dS' + '\n'
    f.write(head)
    for i,j in sp.items():
        st = str(i) + '\t' + '\t'.join(j) + '\n'
        f.write(st)
        
    f.close()
